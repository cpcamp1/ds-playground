# %% [markdown]
# ## Week 13 Homework
# This week, you learned about neural networks and how their creation led to the creation of LLMs. For this homework, we'll focus on how we utilize LLMs to simplify tasks.

# %% [markdown]
# ### Part 1
# Ask the LLM to write an abstract about your findings for your capstone business problem. Give it a brief explanation of what the capstone is about.
#
# **TODO:** Record the LLM's first response here. What's good about this response? What could be better?

# %% [markdown]
# ### Part 2
# Give the LLM additional information about your capstone work and see how that changes its explanation.
#
# **TODO:** Record the LLM's second response here. What's better about this version?

# %% [markdown]
# ### Part 3
# Throw this fact in your prompt: Red Ventures has been in operation since 2000.
#
# **TODO:** Record the LLM's response. How did this change your capstone paragraph?

# %% [markdown]
# ### Part 4
# Update your prompt to include a "system prompt" that says something along the lines of: "You are a data science student that wants to summarize your final project in a short paper. Write the abstract with the following information:"
#
# **TODO:** Record the LLM's response. Did this improve the explanation at all?

# %% [markdown]
# ### Part 5
# Now, prompt the LLM with: "Forget everything you've been told before this. Tell me about a machine learning model that would be beneficial for my online website, and include potential outcomes."
#
# **TODO:** Record the LLM's response. Why do you think this was the recommendation, based on what you know about LLMs?

# %% [markdown]
# ### Part 6
# Get the LLM to write code to generate a plot for your capstone paper.
# Hints: Include the names of the columns you want to use and the name of the dataframe.

# %%
## TODO: Insert the LLM's code here

# %% [markdown]
# **TODO:** Were there any issues with the code the LLM provided? What adjustments would you need to make to make it work?

# %% [markdown]
# ## Submission
#
# Commit your completed **Week_13_LLM_Homework.ipynb** notebook to your personal Github repo you shared with the faculty.
